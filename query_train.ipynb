# %%
import flor
flor.utils.latest(flor.dataframe("val_acc", "val_recall"))

# %%
import flor
flor.utils.latest(flor.dataframe("loss"))
# Out:
#      epochs epochs_value  steps      projid              tstamp  filename  \
# 0         1            0      1  pdf_parser 2024-05-08 12:43:04  train.py
# 1         1            0      2  pdf_parser 2024-05-08 12:43:04  train.py
# 2         1            0      3  pdf_parser 2024-05-08 12:43:04  train.py
# 3         1            0      4  pdf_parser 2024-05-08 12:43:04  train.py
# 4         1            0      5  pdf_parser 2024-05-08 12:43:04  train.py
# ..      ...          ...    ...         ...                 ...       ...
# 700      15           14     43  pdf_parser 2024-05-08 12:43:04  train.py
# 701      15           14     44  pdf_parser 2024-05-08 12:43:04  train.py
# 702      15           14     45  pdf_parser 2024-05-08 12:43:04  train.py
# 703      15           14     46  pdf_parser 2024-05-08 12:43:04  train.py
# 704      15           14     47  pdf_parser 2024-05-08 12:43:04  train.py
#
#                     loss
# 0     0.9212393760681152
# 1    0.47564783692359924
# ...
