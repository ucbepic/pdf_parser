# %%
import pandas as pd
import wikipediaapi
import re
import os
import json

# %%
with open(os.path.join('public', '50_states.json'), 'r') as f:
    states = json.load(f)
states
# Out:
# {'AL': 'Alabama',
#  'AK': 'Alaska',
#  'AZ': 'Arizona',
#  'AR': 'Arkansas',
#  'CA': 'California',
#  'CO': 'Colorado',
#  'CT': 'Connecticut',
#  'DE': 'Delaware',
#  'FL': 'Florida',
#  'GA': 'Georgia',
#  'HI': 'Hawaii',
#  'ID': 'Idaho',
#  'IL': 'Illinois',
#  'IN': 'Indiana',
#  'IA': 'Iowa',
#  'KS': 'Kansas',
#  'KY': 'Kentucky',
#  'LA': 'Louisiana',
#  'ME': 'Maine',
#  'MD': 'Maryland',
#  'MA': 'Massachusetts',
#  'MI': 'Michigan',
#  'MN': 'Minnesota',
#  'MS': 'Mississippi',
#  'MO': 'Missouri',
#  'MT': 'Montana',
#  'NE': 'Nebraska',
#  'NV': 'Nevada',
#  'NH': 'New Hampshire',
#  'NJ': 'New Jersey',
#  'NM': 'New Mexico',
#  'NY': 'New York',
#  'NC': 'North Carolina',
#  'ND': 'North Dakota',
#  'OH': 'Ohio',
#  'OK': 'Oklahoma',
#  'OR': 'Oregon',
#  'PA': 'Pennsylvania',
#  'RI': 'Rhode Island',
#  'SC': 'South Carolina',
#  'SD': 'South Dakota',
#  'TN': 'Tennessee',
#  'TX': 'Texas',
#  'UT': 'Utah',
#  'VT': 'Vermont',
#  'VA': 'Virginia',
#  'WA': 'Washington',
#  'WV': 'West Virginia',
#  'WI': 'Wisconsin',
#  'WY': 'Wyoming'}

# %%
all_signatures = pd.read_csv(os.path.join('public', '22march2024', 'all_signatures.txt'), delimiter='\t', header=None)
all_signatures = all_signatures.rename(columns={0: 'name', 1: 'state', 2: 'district'})
all_signatures
# Out:
#                      name          state  district
# 0    1. James P. McGovern  Massachusetts         2
# 1         2. Gabe Vasquez     New Mexico         2
# 2     3. Stephen F. Lynch  Massachusetts         8
# 3      4. Matt Cartwright   Pennsylvania         8
# 4      5. Earl Blumenauer         Oregon         3
# ..                    ...            ...       ...
# 186    187. Lloyd Doggett          Texas        37
# 187         188. Ken Buck       Colorado         4
# 188      189. Josh Harder     California         9
# 189     190. Kevin Mullin     California        15
# 190  191. Chellie Pingree          Maine         1
#
# [191 rows x 3 columns]

# %%
# regex to match garbage, such as numbers '1. ...' before the full name
garbage = re.compile(r'^\d+\.\s+')
all_signatures['name'] = all_signatures['name'].apply(lambda x: garbage.sub('', x))
all_signatures
# Out:
#                   name          state  district
# 0    James P. McGovern  Massachusetts         2
# 1         Gabe Vasquez     New Mexico         2
# 2     Stephen F. Lynch  Massachusetts         8
# 3      Matt Cartwright   Pennsylvania         8
# 4      Earl Blumenauer         Oregon         3
# ..                 ...            ...       ...
# 186      Lloyd Doggett          Texas        37
# 187           Ken Buck       Colorado         4
# 188        Josh Harder     California         9
# 189       Kevin Mullin     California        15
# 190    Chellie Pingree          Maine         1
#
# [191 rows x 3 columns]

# %% [markdown]
# # Parse Dem Holdouts from PNG

# %%
dem_holdouts = pd.read_csv(os.path.join('public', '22march2024', 'dem_holdouts.txt'), delimiter=',', header=None)
dem_holdouts = dem_holdouts.rename(columns={0: 'name', 1: 'state'})
dem_holdouts

# %%
# Remove parentheses
dem_holdouts.state = dem_holdouts.state.apply(lambda x: re.sub(r'\(|\)', '', x).strip())
dem_holdouts.state = dem_holdouts.state.apply(lambda x: states[x] if x in states else x)
dem_holdouts

# %%
# Fuzzy search: by name, search for the closest match in the all_signatures dataframe
from fuzzywuzzy import process
dem_holdouts['name'].apply(lambda x: (x, process.extractOne(x, all_signatures['name'])))

# %%
import flor
for i, row in flor.loop("us_rep", dem_holdouts.iterrows()):
    flor.log("name", row[0])
    flor.log("state", row[1])
    flor.log("signed", False)
    flor.log("party", "Democrat")
flor.commit()

# %% [markdown]
# # Enter Signatures into DB

# %%
all_signatures
# Out:
#                   name          state  district
# 0    James P. McGovern  Massachusetts         2
# 1         Gabe Vasquez     New Mexico         2
# 2     Stephen F. Lynch  Massachusetts         8
# 3      Matt Cartwright   Pennsylvania         8
# 4      Earl Blumenauer         Oregon         3
# ..                 ...            ...       ...
# 186      Lloyd Doggett          Texas        37
# 187           Ken Buck       Colorado         4
# 188        Josh Harder     California         9
# 189       Kevin Mullin     California        15
# 190    Chellie Pingree          Maine         1
#
# [191 rows x 3 columns]

# %%
print(all_signatures.to_string())
# Out:
#                            name           state  district
# 0             James P. McGovern   Massachusetts         2
# 1                  Gabe Vasquez      New Mexico         2
# 2              Stephen F. Lynch   Massachusetts         8
# 3               Matt Cartwright    Pennsylvania         8
# 4               Earl Blumenauer          Oregon         3
# 5           Jonathan L. Jackson        Illinois         1
# 6                Steny H. Hoyer        Maryland         5
# 7               Donald G. Davis  North Carolina         1
# 8               Scott H. Peters      California        50
# 9                  Wiley Nickel  North Carolina        13
# 10           Katherine M. Clark   Massachusetts         5
# 11              Morgan McGarvey        Kentucky         3
# 12           Hakeem S. Jeffries        New York         8
# 13             Suzan K. DelBene      Washington         1
# 14             Thomas R. Suozzi        New York         3
# 15                   Susan Wild    Pennsylvania         7
# 16                  Lucy McBath         Georgia         7
# 17                Mike Thompson      California         4
# 18           Bennie G. Thompson     Mississippi         2
# 19              Emanuel Cleaver        Missouri         5
# 20                Diana DeGette        Colorado         1
# 21              Doris O. Matsui      California         7
# 22            Salud O. Carbajal      California        24
# 23                     Ami Bera      California         6
# 24                 Joyce Beatty            Ohio         3
# 25                 Val T. Hoyle          Oregon         4
# 26              Richard E. Neal   Massachusetts         1
# 27        Jennifer L. McClellan        Virginia         4
# 28                  David Scott         Georgia        13
# 29                 Patrick Ryan        New York        18
# 30               Andrea Salinas          Oregon         6
# 31           Marilyn Strickland      Washington        10
# 32             Chrissy Houlahan    Pennsylvania         6
# 33                 Mike Quigley        Illinois         5
# 34                 Jahana Hayes     Connecticut         5
# 35               John B. Larson     Connecticut         1
# 36            Sanford D. Bishop         Georgia         2
# 37                Shri Thanedar        Michigan        13
# 38           William R. Keating   Massachusetts         9
# 39             Jake Auchincloss   Massachusetts         4
# 40               J. Luis Correa      California        46
# %%
wiki_wiki = wikipediaapi.Wikipedia("QuorumFinder (rogarcia@berkeley.edu; rlnsanz.github.io)")

for i, row in all_signatures.iterrows():
    full_name = row[0]
    us_state = row[1]
    p = wiki_wiki.page(full_name)
    if p.exists():
        print(row[0], re.findall(pattern, p.summary, re.IGNORECASE))
    else:
        # We need to search for the page
        print(row[0], "not found")
# Out:
# James P. McGovern ['Democratic Party', 'Democratic', 'Republican']
# Gabe Vasquez ['Democratic Party']
# Stephen F. Lynch ['Democrat', 'Democratic']
# Matt Cartwright ['Democratic Party', 'Democratic', 'Republican']
# Earl Blumenauer ['Democratic Party']
# Jonathan L. Jackson not found
# Steny H. Hoyer ['Democrat', 'Democrat', 'Republican', 'Democrat']
# Donald G. Davis ['Democratic Party']
# Scott H. Peters ['Democratic Party']
# Wiley Nickel ['Democratic']
# Katherine M. Clark ['Democratic']
# Morgan McGarvey ['Democrat', 'Democrat']
# Hakeem S. Jeffries ['Democratic', 'Democratic']
# Suzan K. DelBene ['Democratic', 'Republican', 'Republican', 'Democratic', 'Democrat']
# Thomas R. Suozzi ['Democratic Party', 'Republican', 'Democratic', 'Democratic', 'Democratic']
# Susan Wild ['Democrat', 'Democrat']
# Lucy McBath ['Democratic Party', 'Democratic', 'Republican', 'Democratic']
# Mike Thompson []
# Bennie G. Thompson ['Democratic Party', 'Democrat', 'Democrat']
# Emanuel Cleaver ['Democratic Party']
# Diana DeGette ['Democratic Party']
# Doris O. Matsui []
# Salud O. Carbajal ['Democratic Party']
# Ami Bera ['Democratic Party']
# Joyce Beatty ['Democratic Party', 'Democratic', 'Republican']
# Val T. Hoyle not found
# Richard E. Neal ['Democratic Party']
# Jennifer L. McClellan ['Democratic Party', 'Democratic', 'Democratic', 'Republican']
# David Scott []
# Patrick Ryan []
# Andrea Salinas ['Democratic Party']
# Marilyn Strickland ['Democratic Party']
# Chrissy Houlahan ['Democratic Party', 'Republican']
# Mike Quigley ['Democratic Party']
# Jahana Hayes ['Democratic Party', 'Democrat']
# John B. Larson ['Democratic Party', 'Democratic']
# Sanford D. Bishop ['Democratic Party']
# Shri Thanedar ['Democratic Party', 'Democratic']
# William R. Keating ['Democratic Party']
# Jake Auchincloss ['Democratic Party']
# J. Luis Correa ['Democratic Party']
# Valerie P. Foushee ['Democratic Party']
# Sean Casten ['Democratic Party', 'Democrat', 'Democratic', 'Republican']
# Jared Huffman ['Democratic Party', 'Republican']
# Deborah K. Ross ['Democratic Party', 'Democratic', 'Republican']
# Lauren Underwood ['Democratic Party', 'Republican', 'Democratic', 'Democratic']
# Brittany Pettersen ['Democratic Party']
# Jamie Raskin ['Democratic Party']
# Joseph D. Morelle ['Democrat']
# Colin Z. Allred not found
# Gabe Amo ['Democratic']
# Greg Stanton ['Democrat']
# Juan Vargas ['Democratic']
# Lizzie Fletcher ['Democrat']
# Paul Tonko ['Democratic Party', 'Democrat']
# Grace Meng ['Democratic Party']
# Robert C. "Bobby" Scott not found
# Sara Jacobs ['Democratic Party', 'Democratic']
# Seth Magaziner ['Democratic Party']
# Tony Cárdenas ['Democratic Party']
# Suzanne Bonamici ['Democrat']
# Ann M. Kuster ['Democratic Party', 'Democrat']
# Mary Gay Scanlon ['Democratic Party']
# Robin L. Kelly ['Democrat', 'Democratic', 'Democratic']
# Rosa L. DeLauro ['Democratic Party', 'Democratic']
# Jill N. Tokuda ['Democratic Party']
# Sydney Kamlager-Dove ['Democrat']
# Emilia Strong Sykes ['Democratic Party']
# Frederica S. Wilson ['Democratic Party']
# Darren Soto ['Democratic']
# Sheila Jackson Lee ['Democratic Party', 'Democratic', 'Democratic']
# Zoe Lofgren ['Democratic Party']
# John Garamendi ['Democratic Party', 'Democratic', 'Democratic']
# Troy A. Carter ['Democratic Party', 'Democrat']
# Ed Case ['Democratic', 'Democrat', 'Democratic', 'Democratic', 'Democratic', 'Republican', 'Democratic', 'Democrat', 'Democratic']
# Hillary J. Scholten not found
# Yvette D. Clarke ['Democratic Party']
# Bonnie Watson Coleman ['Democratic Party']
# Gregory W. Meeks ['Democratic Party']
# James E. Clyburn ['Democratic', 'Democratic', 'Democrat', 'Democrat', 'Democratic', 'democratic', 'Republican', 'Democratic', 'Democratic', 'Democratic', 'Democratic', 'Democratic']
# Raja Krishnamoorthi ['Democratic Party']
# Jimmy Panetta ['Democratic Party']
# Bradley Scott Schneider ['Democratic Party', 'Republican']
# Steve Cohen []
# Shontel M. Brown ['Democratic Party']
# Rick Larsen ['Democratic Party']
# Donald S. Beyer ['Democratic Party', 'Republican', 'Democratic', 'Republican']
# Ted Lieu ['Democratic', 'Democratic']
# Christopher R. Deluzio not found
# Daniel T. Kildee ['Democratic Party']
# Lisa Blunt Rochester ['Democratic Party']
# James A. Himes ['Democratic Party', 'Democrat']
# Jasmine Crockett ['Democratic Party', 'Democratic', 'Democratic', 'Democratic']
# Adam B. Schiff ['Democratic Party', 'Republican']
# Raul Ruiz []
# Grace F. Napolitano ['Democratic Party', 'Republican', 'Republican']
# Dwight Evans []
# Jeff Jackson []
# Nanette Diaz Barragán ['Democratic Party']
# Glenn Ivey ['Democratic', 'Republican', 'Democratic']
# Yadira Caraveo ['Democrat']
# Sheila Cherfilus-McCormick ['Democratic Party']
# Bill Pascrell ['Democratic Party']
# Seth Moulton ['Democratic Party', 'Democratic']
# Greg Landsman ['Democratic Party']
# Joe Courtney []
# Henry C. "Hank" Johnson not found
# Linda T. Sánchez ['Democratic Party', 'Democratic', 'Democratic']
# Jennifer Wexton ['Democrat', 'Republican', 'Democrat']
# Mike Levin ['Democratic Party']
# Abigail Davis Spanberger ['Democratic Party', 'Republican', 'Republican Party']
# Kathy Castor ['Democrat']
# Janice D. Schakowsky ['Democratic Party']
# Anna G. Eshoo ['Democratic Party']
# Alma S. Adams ['Democrat']
# Josh Gottheimer ['Democratic Party']
# Derek Kilmer ['Democratic Party']
# Betty McCollum ['Democratic']
# Lori Trahan ['Democrat']
# Adam Smith []
# Ruben Gallego ['Democrat', 'Democrat']
# Haley M. Stevens ['Democratic Party', 'Republican']
# Jared Moskowitz ['Democratic Party']
# Brad Sherman ['Democratic Party']
# Brendan F. Boyle ['Democratic']
# Chris Pappas []
# Mark DeSaulnier ['Democratic Party', 'Republican']
# Gwen Moore ['Democratic Party']
# Marie Gluesenkamp Perez ['Democratic Party']
# John P. Sarbanes ['Democratic Party']
# Marcy Kaptur ['Democratic Party']
# Nikki Budzinski ['Democratic Party']
# Jason Crow ['Democratic Party']
# Teresa Leger Fernandez []
# Frank J. Mrvan ['Democratic Party']
# Daniel S. Goldman ['Democratic Party']
# Adriano Espaillat ['Democrat', 'Democratic', 'Democratic', 'Democratic']
# Becca Balint ['Democratic Party']
# Al Green []
# Norma J. Torres ['Democratic Party']
# Kathy E. Manning ['Democratic Party']
# Pete Aguilar ['Democratic', 'Democratic']
# Eric Swalwell ['Democratic Party', 'Democratic', 'Democratic Party']
# Mark Takano ['Democratic Party']
# Bill Foster []
# Susie Lee ['Democrat']
# Julia Brownley ['Democrat']
# Debbie Wasserman Schultz ['Democratic Party', 'Democratic', 'Democratic', 'Democratic']
# Frank Pallone ['Democratic Party']
# C. A. Dutch Ruppersberger ['Democratic Party']
# Jim Costa ['Democratic Party']
# Kweisi Mfume ['Democratic Party', 'Democratic']
# Robert Menendez ['Democratic Party']
# Terri A. Sewell ['Democratic Party', 'Republican', 'Democrat', 'Democrat']
# Elissa Slotkin ['Democratic Party']
# Judy Chu ['Democratic Party', 'Republican', 'Republican']
# Marc A. Veasey ['Democratic']
# Nancy Pelosi ['Democratic Party', 'Democratic Party', 'Democratic', 'Republican Party', 'Democratic', 'Democratic', 'Democratic']
# Maxine Waters ['Democratic Party']
# Dina Titus ['Democratic Party', 'Democratic']
# Eric Sorensen []
# Sylvia R. Garcia ['Democratic Party']
# Henry Cuellar ['Democratic Party', 'Democrat', 'Democratic']
# Joe Neguse ['Democratic Party', 'Democratic']
# David J. Trone ['Democratic', 'Democratic']
# Mikie Sherrill ['Democratic Party']
# Jerrold Nadler ['Democratic Party']
# Angie Craig ['Democratic']
# Nikema Williams ['Democratic Party']
# Ritchie Torres ['Democratic Party', 'Democratic']
# Vicente Gonzalez []
# Madeleine Dean ['Democratic']
# Kim Schrier ['Democratic Party']
# Melanie A. Stansbury ['Democrat']
# Steven Horsford ['Democratic Party', 'Republican', 'Democrat']
# Robert Garcia []
# Donald Norcross ['Democratic Party', 'Democrat']
# Veronica Escobar ['Democratic Party']
# Sharice Davids ['Democratic Party', 'Democrat', 'Democrat', 'Republican']
# Mary Sattler Peltola ['Democratic Party', 'Democratic Party', 'Democrat', 'Democrat']
# Dean Phillips ['Democratic Party', 'Democratic Party', 'Republican', 'Republican', 'Democrat', 'Democrat', 'Democratic']
# Katie Porter ['Democratic']
# Andy Kim []
# Gerald E. Connolly ['Democratic Party']
# Donald M. Payne ['Democratic Party']
# Danny K. Davis ['Democrat', 'Democratic']
# Lloyd Doggett ['Democratic Party']
# Ken Buck ['Republican Party', 'Democrat', 'Republican Party']
# Josh Harder ['Democratic Party', 'Republican']
# Kevin Mullin ['Democratic Party']
# Chellie Pingree ['Democratic Party', 'Republican', 'Democratic']
